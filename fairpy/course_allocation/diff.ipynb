# %%
import random 
import numpy as np
import matplotlib.pyplot as plt
x = np.array([i for i in range(1,5)])
#seq
a = [11.973835468292236, 16.343693733215332, 28.151805877685547, 33.22792840003967]
#process pool
b = [12.250681161880493, 15.303289651870728, 26.049525022506714, 33.96874761581421]
fig, axs = plt.subplots(1,1,figsize=(10,8))
labels = ['100 courses and 400 students', '200 courses and 800 students', 
            '300 courses and 1200 students', '400 courses and 1600 students']

axs.bar(x, a, width=0.3, facecolor='b', edgecolor='b', linewidth=3, alpha=.5, label = "400*i,100*i")
axs.bar(x+0.1, b, width=0.3, facecolor='r', edgecolor='r', linewidth=3, alpha=.5, label = "400*i,100*i")
axs.set_ylabel('time')
axs.set_xlabel("red is using pools and blue is sequential")
axs.set_title('400 *i courses and 100 *i courses with 10 second given in algorithm 1')
# Out:
# Text(0.5, 1.0, '400 *i courses and 100 *i courses with 10 second given in algorithm 1')
